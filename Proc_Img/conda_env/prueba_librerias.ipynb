# %%
#!/usr/bin/env python3
# -*- coding: utf-8 

import importlib
import sys

# %%
try:
    import matplotlib.pyplot as plt
except ImportError as e:
    print(f'Error al importar la librería matplotlib: {e}')
else:
    print('La librería matplotlib se encuentra instalada')

# %%
try:
    import seaborn
except ImportError as e:
    print(f'Error al importar la librería seaborn: {e}')
else:
    print('La librería seaborn se encuentra instalada')

# %%
try:
    import numpy
except ImportError as e:
    print(f'Error al importar la librería numpy: {e}')
else:
    print('La librería numpy se encuentra instalada')

# %%
try:
    import pandas
except ImportError as e:
    print(f'Error al importar la librería pandas: {e}')
else:
    print('La librería pandas se encuentra instalada')

# %%
try:
    import geopandas
except ImportError as e:
    print(f'Error al importar la librería geopandas: {e}')
else:
    print('La librería geopandas se encuentra instalada')

# %%
try:
    import fiona
except ImportError as e:
    print(f'Error al importar la librería fiona: {e}')
else:
    print('La librería fiona se encuentra instalada')

# %%
try:
    import rasterio
except ImportError as e:
    print(f'Error al importar la librería rasterio: {e}')
else:
    print('La librería rasterio se encuentra instalada')

# %%
try:
    import sklearn
except ImportError as e:
    print(f'Error al importar la librería scikit-learn: {e}')
else:
    print('La librería scikit-learn se encuentra instalada')

# %%
try:
    import PIL
except ImportError as e:
    print(f'Error al importar la librería PIL: {e}')
else:
    print('La librería PIL se encuentra instalada')

# %%
try:
    import pyproj
except ImportError as e:
    print(f'Error al importar la librería pyproj: {e}')
else:
    print('La librería pyproj se encuentra instalada')

# %%
try:
    import scipy
except ImportError as e:
    print(f'Error al importar la librería scipy: {e}')
else:
    print('La librería scipy se encuentra instalada')
